# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from getpass import getpass

fre = input("Enter the friend Email Id :")
usr = input('Enter your Email Id:')
pwd = getpass('Enter Password:')
mssg=input("Enter mssg here:")
# open chrome


browser = webdriver.Chrome("chromedriver.exe")
browser.get("https://accounts.google.com/signin/v2/identifier?service=mail&passive=true&rm=false&continue=https%3A%2F%2Fmail.google.com%2Fmail%2F&ss=1&scc=1&ltmpl=default&ltmplcache=2&emr=1&osid=1&flowName=GlifWebSignIn&flowEntry=ServiceLogin")

#fill username and password


username_box = browser.find_element_by_class_name("whsOnd")
username_box.send_keys(usr)
print("Email Id entered")
username_box.send_keys(Keys.RETURN)
time.sleep(10)

password_box = browser.find_element_by_class_name("whsOnd")
password_box.send_keys(pwd)
print("Password entered")
password_box.send_keys(Keys.RETURN)
time.sleep(40)







#email = browser.find_element_by_class_name("whsOnd")
#enter your email id here
#email.send_keys('abhi1996thebond@gmail.com')
#email.send_keys(Keys.RETURN)

#time.sleep(10)


#pwd = browser.find_element_by_class_name("whsOnd")
#enter your password here
#pwd.send_keys('abhi@2011')
#pwd.send_keys(Keys.RETURN)

#time.sleep(40)

for i in range(10):

    time.sleep(3)
    compose = browser.find_element_by_class_name("z0")
    browser.implicitly_wait(5)
    compose.click()

    time.sleep(3)
    to_email = browser.find_element_by_class_name("vO")
    to_email.send_keys(fre)
    to_email.send_keys(Keys.RETURN)

    time.sleep(2)
    msg = browser.find_element_by_class_name("Am")
    msg.send_keys(mssg)
    msg.send_keys(Keys.RETURN)

    time.sleep(2)
    #send message
    send = browser.find_element_by_class_name("gU")
    browser.implicitly_wait(5)
    send.click()

    time.sleep(5)





browser.close()
# Out:
# Enter the friend Email Id :abhi1996thebond@gmail.com
# Enter Email Id:abhi1998thebond@gmail.com
# Enter Password:········
# Enter mssg herehi how r you
# Email Id entered
# Password entered
